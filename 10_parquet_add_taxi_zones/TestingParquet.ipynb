# %%
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
import bokeh
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0e37c8d0-2f7a-499f-b1a8-05befb0c3415">Loading BokehJS ...</span>
#     </div>

# %%
import mpld3
mpld3.enable_notebook()

# %%
df = spark.read.load('/data4/parquet/citibike.parquet')

# %%
df.show(10)
# Out:
# +-------------+----------------+----------------+----------------+--------------------+----------------------+-----------------------+--------------+--------------------+--------------------+---------------------+-------+------------+----------+------+
# |trip_duration|      start_time|       stop_time|start_station_id|  start_station_name|start_station_latitude|start_station_longitude|end_station_id|    end_station_name|end_station_latitude|end_station_longitude|bike_id|   user_type|birth_year|gender|
# +-------------+----------------+----------------+----------------+--------------------+----------------------+-----------------------+--------------+--------------------+--------------------+---------------------+-------+------------+----------+------+
# |         4253|1475863020000000|1475867274000000|            3163|"Central Park Wes...|             40.773407|              -73.97783|          3163|"Central Park Wes...|           40.773407|            -73.97783|  26005|  "Customer"|       NaN|     0|
# |          934|1475863021000000|1475863956000000|            3263|"Cooper Square & ...|             40.729237|              -73.99087|          3230|"Penn Station Valet"|            40.75128|           -73.996925|  23258|"Subscriber"|    1994.0|     1|
# |         1511|1475863021000000|1475864532000000|             461|   "E 20 St & 2 Ave"|             40.735878|              -73.98205|           262|   "Washington Park"|           40.691784|            -73.97373|  24954|"Subscriber"|    1984.0|     1|
# |         1378|1475863021000000|1475864400000000|             426|"West St & Chambe...|              40.71755|              -74.01322|           331|"Pike St & Monroe...|            40.71173|            -73.99193|  25124|"Subscriber"|    1979.0|     2|
# |          531|1475863022000000|1475863553000000|             382|"University Pl & ...|              40.73493|             -73.992004|           348|"W Broadway & Spr...|            40.72491|            -74.00155|  25142|"Subscriber"|    1986.0|     1|
# |         1304|1475863022000000|1475864326000000|             426|"West St & Chambe...|              40.71755|              -74.01322|          2009|"Catherine St & M...|           40.711174|           -73.996826|  20915|"Subscriber"|    1977.0|     1|
# |          244|1475863022000000|1475863266000000|            3310|     "14 St & 7 Ave"|              40.66378|              -73.98397|          3317|     "10 St & 5 Ave"|            40.66863|              -73.987|  17387|"Subscriber"|    1982.0|     1|
# |          323|1475863024000000|1475863347000000|             433|"E 13 St & Avenue A"|             40.729553|             -73.980576|           483|   "E 12 St & 3 Ave"|            40.73223|             -73.9889|  26430|"Subscriber"|    1983.0|     2|
# |         1030|1475863024000000|1475864055000000|             367|"E 53 St & Lexing...|              40.75828|             -73.970695|          3161|"W 76 St & Columb...|           40.780186|            -73.97729|  23181|"Subscriber"|    1975.0|     1|
# |         1027|1475863024000000|1475864052000000|             423|   "W 54 St & 9 Ave"|              40.76585|              -73.98691|          3428|   "8 Ave & W 16 St"|           40.740982|             -74.0017|  18048|"Subscriber"|    1987.0|     1|
# +-------------+----------------+----------------+----------------+--------------------+----------------------+-----------------------+--------------+--------------------+--------------------+---------------------+-------+------------+----------+------+
# only showing top 10 rows

# %%
df.dtypes
# Out:
# [('trip_duration', 'int'),
#  ('start_time', 'bigint'),
#  ('stop_time', 'bigint'),
#  ('start_station_id', 'int'),
#  ('start_station_name', 'string'),
#  ('start_station_latitude', 'float'),
#  ('start_station_longitude', 'float'),
#  ('end_station_id', 'int'),
#  ('end_station_name', 'string'),
#  ('end_station_latitude', 'float'),
#  ('end_station_longitude', 'float'),
#  ('bike_id', 'int'),
#  ('user_type', 'string'),
#  ('birth_year', 'float'),
#  ('gender', 'int')]

# %%
from pyspark.sql.types import IntegerType, TimestampType, DateType, DateConverter, DatetimeConverter
import pyspark.sql.functions as func

# %% [markdown]
# ## Fastparquet outputs timestamps in microseconds by default. This does the conversion.

# %%
df = df.withColumn("start_time", func.to_utc_timestamp(func.from_unixtime(df.start_time/1000000), "UTC"))
df = df.withColumn("stop_time", func.to_utc_timestamp(func.from_unixtime(df.stop_time/1000000), "UTC"))

# %%
df = df.repartition("start_station_id")
df = df.sortWithinPartitions("start_time")

# %% [markdown]
# ## Partitioned write

# %%
df.write.parquet('/data4/parquet_spark/citibike.parquet', mode='overwrite', compression="snappy", partitionBy=['start_station_id'])

# %%
df2 = spark.sql('SELECT (hour(start_time)*60+minute(start_time)+hour(start_time)/60.0)/60.0 as start_time from parquet.`/data4/parquet_spark/citibike.parquet` where start_station_id=482')
df3 = spark.sql('SELECT (hour(start_time)*60+minute(start_time)+hour(start_time)/60.0)/60.0 as start_time from parquet.`/data4/parquet_spark/citibike.parquet` where start_station_id=3163')

# %% [markdown]
# ## Partitioned read

# %%
df4 = spark.sql('''SELECT (hour(start_time)*60+minute(start_time)+hour(start_time)/60.0)/60.0 as start_time 
                    from parquet.`/data4/parquet_spark/citibike.parquet/start_station_id=482`''')
df5 = spark.sql('''SELECT (hour(start_time)*60+minute(start_time)+hour(start_time)/60.0)/60.0 as start_time 
                    from parquet.`/data4/parquet_spark/citibike.parquet/start_station_id=3163`''')

# %%
import seaborn
import numpy as np
from matplotlib import pyplot as plt
from bokeh import mpl

# %%
import sys

# %%
seaborn.distplot(df2.toPandas()['start_time'].astype(np.float32), bins=np.linspace(0, 24, 97))
seaborn.distplot(df3.toPandas()['start_time'].astype(np.float32), bins=np.linspace(0, 24, 97))
# plt.xlim(-1, 25)
mpld3.display()
# print(mpld3.fig_to_html(plt.gcf()))
# Out:
# /home/shekhar/anaconda3/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
# <style>
#
# </style>
#
# <div id="fig_el236791405574484073609529191473"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el236791405574484073609529191473", {"id": "el23679140557448407360", "data": {"data95": [[23.5, 0.0], [23.75, 0.0], [23.75, 0.0026275568274202465], [23.5, 0.0026275568274202465]], "data91": [[22.5, 0.0, 0.0], [22.75, 0.0, 0.0], [22.75, 0.0029137263828818575, 0.0004725786252687791], [22.5, 0.0029137263828818575, 0.0004725786252687791]], "data36": [[8.25, 0.0, 0.0], [8.5, 0.0, 0.0], [8.5, 0.05096419628629963, 0.06899647928924174], [8.25, 0.05096419628629963, 0.06899647928924174]], "data90": [[22.25, 0.0, 0.0], [22.5, 0.0, 0.0], [22.5, 0.003408019251406458, 0.0007561258004300465], [22.25, 0.003408019251406458, 0.0007561258004300465]], "data88": [[21.75, 0.0, 0.0], [22.0, 0.0, 0.0], [22.0, 0.004422620402588534, 0.0013232201507525814], [21.75, 0.004422620402588534, 0.0013232201507525814]], "data47": [[11.0, 0.0, 0.0], [11.25, 0.0, 0.0], [11.25, 0.05580306331501415, 0.08695446704945535], [11.0, 0.05580306331501415, 0.08695446704945535]], "data92": [[22.75, 0.0], [23.0, 0.0], [23.0, 0.0025495105850216254], [22.75, 0.0025495105850216254]], "data65": [[15.75, 0.0, 0.0], [16.0, 0.0, 0.0], [16.0, 0.06696367597801697, 0.04092530894827627], [15.75, 0.06696367597801697, 0.04092530894827627]], "data67": [[16.25, 0.0, 0.0], [16.5, 0.0, 0.0], [16.5, 0.05439823095183897, 0.036388554145695994], [16.25, 0.05439823095183897, 0.036388554145695994]], "data32": [[7.25, 0.0, 0.0], [7.5, 0.0, 0.0], [7.5, 0.0471399304087672, 0.06445972448666147], [7.25, 0.0471399304087672, 0.06445972448666147
0.0], [16.25, 0.0, 0.0], [16.25, 0.056245325355273, 0.04687979962666289], [16.0, 0.056245325355273, 0.04687979962666289]], "data57": [[13.75, 0.0, 0.0], [14.0, 0.0, 0.0], [14.0, 0.08200058534681799, 0.08799414002504667], [13.75, 0.08200058534681799, 0.08799414002504667]], "data62": [[15.0, 0.0, 0.0], [15.25, 0.0, 0.0], [15.25, 0.0755487626418653, 0.06720068051322038], [15.0, 0.0755487626418653, 0.06720068051322038]], "data11": [[2.0, 0.0, 0.0], [2.25, 0.0, 0.0], [2.25, 0.023700042275047965, 0.007750289454407977], [2.0, 0.023700042275047965, 0.007750289454407977]], "data93": [[23.0, 0.0, 0.0], [23.25, 0.0, 0.0], [23.25, 0.0017950635751682873, 0.00037806290021502327], [23.0, 0.0017950635751682873, 0.00037806290021502327]], "data54": [[13.0, 0.0, 0.0], [13.25, 0.0, 0.0], [13.25, 0.06842053916945791, 0.08553673117364902], [13.0, 0.06842053916945791, 0.08553673117364902]], "data79": [[19.25, 0.0, 0.0], [19.5, 0.0, 0.0], [19.5, 0.019511560599655295, 0.01427187448311 ...

# %% [markdown]
# ## Reading the parquet file from Spark in Dask/Fastparquet does not work because of datetime incompatibilities

# %%
from glob import glob

# %%
import dask.dataframe as dd
import fastparquet

# %%
m = fastparquet.ParquetFile(glob('/data4/parquet_spark/citibike.parquet/start_station_id=482/*parquet')[0])

# %%
m
# Out:
# <Parquet File: {'columns': ['trip_duration', 'start_time', 'stop_time', 'start_station_name', 'start_station_latitude', 'start_station_longitude', 'end_station_id', 'end_station_name', 'end_station_latitude', 'end_station_longitude', 'bike_id', 'user_type', 'birth_year', 'gender'], 'categories': [], 'name': '/data4/parquet_spark/citibike.parquet/start_station_id=482/part-r-00140-f8a97310-1d33-4890-9550-c192fb0d03c5.snappy.parquet', 'rows': 153755}>

# %%
m.to_pandas(columns='trip_duration')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-5cf096212f69> in <module>()
# ----> 1 m.to_pandas(columns='trip_duration')
#
# /home/shekhar/anaconda3/lib/python3.5/site-packages/fastparquet/api.py in to_pandas(self, columns, categories, filters, index, timestamp96)
#     300                     self.read_row_group(rg, columns, categories, infile=f,
#     301                                         index=index, assign=parts,
# --> 302                                         timestamp96=timestamp96)
#     303                     start += rg.num_rows
#     304         else:
#
# /home/shekhar/anaconda3/lib/python3.5/site-packages/fastparquet/api.py in read_row_group(self, rg, columns, categories, infile, index, assign, timestamp96)
#     154                 infile, rg, columns, categories, self.helper, self.cats,
#     155                 self.selfmade, index=index, assign=assign,
# --> 156                 timestamp96=timestamp96)
#     157         if ret:
#     158             return df
#
# /home/shekhar/anaconda3/lib/python3.5/site-packages/fastparquet/core.py in read_row_group(file, rg, columns, categories, schema_helper, cats, selfmade, index, assign, timestamp96)
#     301         raise RuntimeError('Going with pre-allocation!')
#     302     read_row_group_arrays(file, rg, columns, categories, schema_helper,
# --> 303                           cats, selfmade, assign=assign, timestamp96=timestamp96)
#     304
#     305     for cat in cats:
#
# /home/shekhar/anaconda3/lib/python3.5/site-packages/fastparquet/core.py in read_row_group_arrays(file, rg, columns, categories, schema_helper, cats, selfmade, assign, timestamp96)
#     288         mr = name in timestamp96
#     289         read_col(column, schema_helper, file, use_cat=use,
# --> 290                  selfmade=selfmade, assign=out[name],
#     291                  catdef=out[name+'-catdef'] if use else None,
#     292                  timestamp96=mr)
#
# KeyError: 'trip_duration'
